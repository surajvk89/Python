# %% [markdown]
# # Hands-on Analysis of ordered categorical variables

# %% [markdown]
# ## Importing dataset

# %%
import numpy as np
import pandas as pd

sc = pd.read_csv("tendulkar_ODI.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f2329f4d3ffd> in <module>()
#       2 import pandas as pd
#       3
# ----> 4 sc = pd.read_csv("tendulkar_ODI.csv")
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %% [markdown]
# ## Cleaning the dataset

# %%
# remove * in Runs column
# replace DNB by 0 in Runs column
# replace - by 0 in 4s column
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1    0    -    2   0  0       0   5    caught    2
# 1             2    0    2    2   0  0       0   5    caught    2
# 2             3   36   51   39   5  0    92.3   6    caught    1
# 3             4   19   38   35   1  1   54.28   4    bowled    2
# 4             5   31   31   26   3  0  119.23   6    bowled    2
# ..          ...  ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291   18   21   14   2  0  128.57   2    caught    2
# 291         292    2    9    6   0  0   33.33   2    caught    2
# 292         293    3   21   12   0  0      25   2    caught    2
# 293         294   14   34   15   2  0   93.33   2   run out    2
# 294         295  114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date
# 0       v Pakistan  Gujranwala  18-Dec-89
# 1    v New Zealand     Dunedin   1-Mar-90
# 2    v New Zealand  Wellington   6-Mar-90
# ...

# %% [markdown]
# ##Write the code for the following and answer questions based on them on the platform.

# %% [markdown]
# Plot a bar chart showing runs scored on the x-axis and frequency/count on the y-axis.

# %%
# Code here

# %% [markdown]
# Plot a histogram of the number of 4s hit by Tendulkar in innings.

# %%
# Code here

# %% [markdown]
# # Summary metrics

# %% [markdown]
# ## Box Plot Analysis

# %% [markdown]
# Now lets plot a Boxplot on incomes dataset.  This Boxplot will show range of income from the incomes dataset. We will be able to spot median, Q1, Q2, Q3, Q4, IQR from the plot.

# %%
import matplotlib.pyplot as plt        # importing required libraries
import pandas as pd

inc = pd.read_csv("income.csv")        # importing dataset
 
inc.boxplot()                          # plotting boxplot 
plt.show()                             # displaying the plot

# %% [markdown]
# New Section
